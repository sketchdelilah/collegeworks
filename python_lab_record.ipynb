# %% [markdown]
# <a href="https://colab.research.google.com/github/sketchdelilah/collegeworks/blob/main/python_lab_record.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find area and perimeter of circle.

# %%
r=int(input("Enter the radius:"))
perimeter= 2 * 3.14 * r
area= 3.14 * r * r
print("Area of circle:", area)
print("Perimeter of circle:", perimeter)
# Out:
# Enter the radius: 7
# Area of circle: 153.86
# Perimeter of circle: 43.96

# %% [markdown]
# Swap two numbers.

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
print("a=",a)
print("b=",b)
c=a
a=b
b=c
print("After swapped,a=",a)
print("b=",b)
# Out:
# Enter the first number:9
# Enter the second number:7
# a= 9
# b= 7
# After swapped,a= 7
# b= 9

# %% [markdown]
# Find the largest of three numbers.

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))
if a>b and a>c:
  print("a is largest")
elif b>a and b>c:
  print("b is largest")
else:
  print("c is largest")
# Out:
# Enter the first number:6
# Enter the second number:3
# Enter the third number:0
# a is largest

# %% [markdown]
# Perform the arithmetic operations of two numbers.

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
print("Addition: ", a+b)
print("Subtraction: ", a-b)
print("Multiplication: ", a*b)
print("Division: ", a/b)
print("Modulus: ", a%b)
print("Exponent: ", a**b)
print("Floor division: ", a//b)
# Out:
# Enter the first number:7
# Enter the second number:10
# Addition:  17
# Subtraction:  -3
# Multiplication:  70
# Division:  0.7
# Modulus:  7
# Exponent:  282475249
# Floor division:  0

# %% [markdown]
# To print the "n" multiples of a number.

# %%
a = int(input("Enter the number:"))
n = int(input("Enter the range:"))
for i in range (1, n+1):
  print(i, "*", a, "=", i*a)
# Out:
# Enter the number:7
# Enter the range:12
# 1 * 7 = 7
# 2 * 7 = 14
# 3 * 7 = 21
# 4 * 7 = 28
# 5 * 7 = 35
# 6 * 7 = 42
# 7 * 7 = 49
# 8 * 7 = 56
# 9 * 7 = 63
# 10 * 7 = 70
# 11 * 7 = 77
# 12 * 7 = 84

# %% [markdown]
# Find the sum of first 100 even numbers.

# %%
sum = 0
for i in range (1,101):
  sum = sum + i*2
print("Sum:", sum)
# Out:
# Sum: 10100

# %% [markdown]
# Find the factorial of a number.

# %%
a = int(input("Enter the number:"))
fact = 1
for i in range(1, a+1):
  fact = fact * i
print("Factorial:", fact)
# Out:
# Enter the number:7
# Factorial: 5040

# %% [markdown]
# Find the number of digits.

# %%
a = int(input("Enter the number:"))
count = 0
while a>0:
  a = a//10
  count = count + 1
print("The number of digits:", count)
# Out:
# Enter the number:56890
# The number of digits: 5

# %% [markdown]
# Check whether a year is leap year or not.

# %%
year = int(input("Enter the year:"))
if (year%400==0) | (year%4==0) & (year%100==0):
  print("The year is leap")
else:
  print("The year is non leap")
# Out:
# Enter the year:2026
# The year is non leap

# %% [markdown]
# Find the roots of a quadratic equation.

# %%
import math
a = int(input("Enter the value of a:"))
b = int(input("Enter the value of b:"))
c = int(input("Enter the value of c:"))
d = b*b - 4*a*c
root1 = ((-b)+d)/2*a
root2 = ((-b)+(-d))/2*a
print("Root 1:", root1)
print("Root 2:", root2)
# Out:
# Enter the value of a:1
# Enter the value of b:-5
# Enter the value of c:6
# Root 1: 3.0
# Root 2: 2.0
